# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/RELIANCE.NS.csv')
data
# Out:
#             Date         Open         High          Low        Close  \
# 0     2000-01-03    33.917892    35.945827    33.917892    35.945827
# 1     2000-01-04    36.902668    38.823490    35.888702    38.823490
# 2     2000-01-05    36.652744    41.115627    36.652744    40.344440
# 3     2000-01-06    41.272720    42.943623    41.272720    42.036766
# 4     2000-01-07    42.129593    45.399994    41.843967    44.921570
# ...          ...          ...          ...          ...          ...
# 6074  2024-04-23  2958.000000  2987.000000  2911.100098  2918.649902
# 6075  2024-04-24  2927.000000  2937.100098  2899.000000  2900.350098
# 6076  2024-04-25  2885.000000  2935.949951  2883.000000  2919.949951
# 6077  2024-04-26  2927.899902  2930.000000  2900.000000  2905.100098
# 6078  2024-04-29  2900.000000  2935.800049  2900.000000  2930.050049
#
#         Adj Close       Volume
# 0       26.684866   31204789.0
# 1       28.821142   66436055.0
# 2       29.950235  187894923.0
# ...

# %%
data['Date']=pd.to_datetime(data['Date'])
data.set_index('Date',inplace=True)

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03    33.917892    35.945827    33.917892    35.945827    26.684866
# 2000-01-04    36.902668    38.823490    35.888702    38.823490    28.821142
# 2000-01-05    36.652744    41.115627    36.652744    40.344440    29.950235
# 2000-01-06    41.272720    42.943623    41.272720    42.036766    31.206556
# 2000-01-07    42.129593    45.399994    41.843967    44.921570    33.348133
# ...                 ...          ...          ...          ...          ...
# 2024-04-23  2958.000000  2987.000000  2911.100098  2918.649902  2918.649902
# 2024-04-24  2927.000000  2937.100098  2899.000000  2900.350098  2900.350098
# 2024-04-25  2885.000000  2935.949951  2883.000000  2919.949951  2919.949951
# 2024-04-26  2927.899902  2930.000000  2900.000000  2905.100098  2905.100098
# 2024-04-29  2900.000000  2935.800049  2900.000000  2930.050049  2930.050049
#
#                  Volume
# Date
# ...

# %%
data.shape
# Out:
# (6079, 6)

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  6069.000000  6069.000000  6069.000000  6069.000000  6069.000000
# mean    689.282224   697.132526   680.887468   688.717071   665.596257
# std     744.042341   751.140627   736.631838   743.652502   746.829061
# min      29.347902    31.347273    28.155420    29.019436    21.542969
# 25%     114.392555   116.963173   113.971260   115.435089   100.121124
# 50%     431.793610   437.051025   425.621887   431.610748   396.301300
# 75%     852.798096   861.164246   843.151917   851.518066   828.857910
# max    3011.550049  3024.899902  2974.449951  3014.800049  3014.800049
#
#              Volume
# count  6.069000e+03
# mean   1.759492e+07
# std    1.927247e+07
# min    0.000000e+00
# 25%    6.592663e+06
# 50%    1.052491e+07
# 75%    2.120097e+07
# max    3.161448e+08

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6079 entries, 2000-01-03 to 2024-04-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       6069 non-null   float64
#  1   High       6069 non-null   float64
#  2   Low        6069 non-null   float64
#  3   Close      6069 non-null   float64
#  4   Adj Close  6069 non-null   float64
#  5   Volume     6069 non-null   float64
# dtypes: float64(6)
# memory usage: 332.4 KB

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS(EDA-1)**

# %% [markdown]
# **1.Handling Missing Values**

# %%
data.isnull().sum()
# Out:
# Open         10
# High         10
# Low          10
# Close        10
# Adj Close    10
# Volume       10
# dtype: int64

# %%
# way-1 : df.dropna(inplace=True)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum() #after droping missing values
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03    33.917892    35.945827    33.917892    35.945827    26.684866
# 2000-01-04    36.902668    38.823490    35.888702    38.823490    28.821142
# 2000-01-05    36.652744    41.115627    36.652744    40.344440    29.950235
# 2000-01-06    41.272720    42.943623    41.272720    42.036766    31.206556
# 2000-01-07    42.129593    45.399994    41.843967    44.921570    33.348133
# ...                 ...          ...          ...          ...          ...
# 2024-04-23  2958.000000  2987.000000  2911.100098  2918.649902  2918.649902
# 2024-04-24  2927.000000  2937.100098  2899.000000  2900.350098  2900.350098
# 2024-04-25  2885.000000  2935.949951  2883.000000  2919.949951  2919.949951
# 2024-04-26  2927.899902  2930.000000  2900.000000  2905.100098  2905.100098
# 2024-04-29  2900.000000  2935.800049  2900.000000  2930.050049  2930.050049
#
#                  Volume
# Date
# ...

# %%
data.shape
# Out:
# (6069, 6)

# %% [markdown]
# **2.Handling Duplicates**

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data[data.duplicated()]
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2000-03-20  33.53944  33.53944  33.53944  33.53944  24.898451     0.0

# %%
data=data.drop_duplicates(ignore_index=True)

# %%
data.duplicated().sum() #after droping duplicates
# Out:
# 0

# %% [markdown]
# **3.Outliers**

# %%
Q1=data['Open'].quantile(0.25)
Q1
# Out:
# 114.9281045

# %%
Q3=data['Open'].quantile(0.75)
Q3
# Out:
# 852.8666842499999

# %%
IQR=Q3-Q1
IQR
# Out:
# 737.9385797499999

# %%
Lower_Extreme=Q1-1.5*IQR
Lower_Extreme
# Out:
# -991.9797651249999

# %%
Upper_Extreme=Q3+1.5*IQR
Upper_Extreme
# Out:
# 1959.7745538749998

# %%
data.boxplot('Open')
# Out:
# <Axes: >

# %%
data_outliers=data[(data.Open<Lower_Extreme) | (data.Open>Upper_Extreme)]
data_outliers
# Out:
#              Open         High          Low        Close    Adj Close  \
# 5137  2011.031738  2029.491699  1964.051025  1990.171875  1969.849609
# 5138  1990.171875  2025.061279  1985.049194  2010.016357  1989.491333
# 5139  2010.201050  2014.723633  1911.024658  1935.207275  1915.446045
# 5144  2001.986328  2026.907227  1955.190186  1962.712646  1942.670654
# 5145  1990.910278  2000.786377  1945.498657  1969.773560  1949.659546
# ...           ...          ...          ...          ...          ...
# 6063  2958.000000  2987.000000  2911.100098  2918.649902  2918.649902
# 6064  2927.000000  2937.100098  2899.000000  2900.350098  2900.350098
# 6065  2885.000000  2935.949951  2883.000000  2919.949951  2919.949951
# 6066  2927.899902  2930.000000  2900.000000  2905.100098  2905.100098
# 6067  2900.000000  2935.800049  2900.000000  2930.050049  2930.050049
#
#           Volume
# 5137  40152413.0
# 5138  27557211.0
# 5139  36331699.0
# 5144  37274996.0
# 5145  24661487.0
# ...

# %%
data_no_outliers=data[(data.Open>Lower_Extreme) & (data.Open<Upper_Extreme)]
data_no_outliers
# Out:
#              Open         High          Low        Close    Adj Close  \
# 0       33.917892    35.945827    33.917892    35.945827    26.684866
# 1       36.902668    38.823490    35.888702    38.823490    28.821142
# 2       36.652744    41.115627    36.652744    40.344440    29.950235
# 3       41.272720    42.943623    41.272720    42.036766    31.206556
# 4       42.129593    45.399994    41.843967    44.921570    33.348133
# ...           ...          ...          ...          ...          ...
# 5394  1951.498169  1988.879639  1942.222046  1969.912109  1956.594116
# 5396  1920.762329  1928.884766  1907.378784  1917.208740  1904.246948
# 5397  1921.685303  1950.298340  1914.070557  1927.269531  1914.239746
# 5398  1935.484131  1956.759277  1922.977539  1954.267212  1941.054932
# 5400  1954.267212  1984.357056  1946.560181  1980.434204  1967.045044
#
#            Volume
# 0      31204789.0
# 1      66436055.0
# 2     187894923.0
# 3     109810562.0
# 4     139140630.0
# ...

# %%
data_no_outliers.boxplot('Open')
plt.show()

# %% [markdown]
# **4.Correlation**

# %%
corr=data[['Open','Close','Low','High','Adj Close','Volume']].corr()
corr
# Out:
#                Open     Close       Low      High  Adj Close    Volume
# Open       1.000000  0.999781  0.999888  0.999894   0.999589 -0.340030
# Close      0.999781  1.000000  0.999905  0.999912   0.999811 -0.339691
# Low        0.999888  0.999905  1.000000  0.999856   0.999753 -0.341141
# High       0.999894  0.999912  0.999856  1.000000   0.999689 -0.338564
# Adj Close  0.999589  0.999811  0.999753  0.999689   1.000000 -0.334447
# Volume    -0.340030 -0.339691 -0.341141 -0.338564  -0.334447  1.000000

# %%
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# **5.Covariance**

# %%
cov=data[['Open','Close','Low','High','Adj Close','Volume']].cov()
cov
# Out:
#                    Open         Close           Low          High  \
# Open       5.536194e+05  5.532082e+05  5.480445e+05  5.588414e+05
# Close      5.532082e+05  5.530394e+05  5.477665e+05  5.585589e+05
# Low        5.480445e+05  5.477665e+05  5.426468e+05  5.532550e+05
# High       5.588414e+05  5.585589e+05  5.532550e+05  5.642326e+05
# Adj Close  5.554664e+05  5.552988e+05  5.500243e+05  5.608217e+05
# Volume    -4.876026e+09 -4.868612e+09 -4.843232e+09 -4.901326e+09
#
#               Adj Close        Volume
# Open       5.554664e+05 -4.876026e+09
# Close      5.552988e+05 -4.868612e+09
# Low        5.500243e+05 -4.843232e+09
# High       5.608217e+05 -4.901326e+09
# Adj Close  5.577779e+05 -4.813945e+09
# Volume    -4.813945e+09  3.714382e+14

# %%
sns.pairplot(data,hue=None)
plt.show()

# %% [markdown]
# **FEATURE ENGINEERING(EDA-2)**

# %% [markdown]
# **Min-Max Scaler**

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
min_max=MinMaxScaler(feature_range=(0,1)) #converting all columns into same format of range(0,1)
df=min_max.fit_transform(data)

set_printoptions(precision=10) #transformed array data
print(df[0:6,:])
# Out:
# [[0.0015324213 0.0015361527 0.001955837  0.0023197923 0.0017178267
#   0.0987041027]
#  [0.0025332843 0.0024974396 0.0026247484 0.0032835815 0.0024315229
#   0.210144385 ]
#  [0.0024494792 0.0032631309 0.0028840715 0.0037929793 0.002808735
#   0.5943318435]
#  [0.0039986619 0.0038737752 0.0044521347 0.0043597744 0.0032284521
#   0.3473426142]
#  [0.0042859908 0.004694329  0.0046460213 0.0053259553 0.0039439192
#   0.4401167728]
#  [0.005358686  0.004732493  0.0052422251 0.005036579  0.0037296325
#   0.2971706838]]

# %%
# converting transformed array to dataframe
df=pd.DataFrame(df,columns=data.columns,index=data.index)
df
# Out:
#           Open      High       Low     Close  Adj Close    Volume
# 0     0.001532  0.001536  0.001956  0.002320   0.001718  0.098704
# 1     0.002533  0.002497  0.002625  0.003284   0.002432  0.210144
# 2     0.002449  0.003263  0.002884  0.003793   0.002809  0.594332
# 3     0.003999  0.003874  0.004452  0.004360   0.003228  0.347343
# 4     0.004286  0.004694  0.004646  0.005326   0.003944  0.440117
# ...        ...       ...       ...       ...        ...       ...
# 6063  0.982043  0.987339  0.978498  0.967797   0.967878  0.023099
# 6064  0.971648  0.970670  0.974392  0.961668   0.961764  0.016547
# 6065  0.957565  0.970286  0.968961  0.968233   0.968312  0.025216
# 6066  0.971950  0.968299  0.974731  0.963259   0.963351  0.014889
# 6067  0.962595  0.970236  0.974731  0.971615   0.971686  0.011463
#
# [6068 rows x 6 columns]

# %% [markdown]
# **Visualizations**

# %% [markdown]
# **1.Subplot**

# %%
#Increasing trend is observed

plt.figure(figsize=(10,10))
# first subplot
plt.subplot(3, 2, 1)
plt.plot(df['Open'],color='red')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Open')

# second subplot
plt.subplot(3, 2, 2)
plt.plot(df['High'],color='green')
plt.xlabel('Date')
plt.ylabel('High Price')
plt.title('High')

# third subplot
plt.subplot(3, 2, 3)
plt.plot(df['Low'],color='red')
plt.xlabel('Date')
plt.ylabel('Low Price')
plt.title('Low')

# fourth subplot
plt.subplot(3, 2, 4)
plt.plot(df['Close'],color='green')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close')

# fifth subplot
plt.subplot(3, 2, 5)
plt.plot(df['Adj Close'],color='red')
plt.xlabel('Date')
plt.ylabel('Adj Price')
plt.title('Adj Close')

# sixth subplot
plt.subplot(3, 2, 6)
plt.plot(df['Volume'],color='green')
plt.xlabel('Date')
plt.ylabel('Stocks Volume')
plt.title('Volume')

# Adjusting layout to prevent overlap
plt.tight_layout()

# Displaying the plot
plt.show()

# %% [markdown]
# **2.Scatter Plot**

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Low'], df['High'], color='blue')
plt.title('Scatter Plot of Low vs High')
plt.xlabel('Low')
plt.ylabel('High')
plt.show()

# %% [markdown]
# **3.Histogram**

# %%
# Ploting Histogram
plt.figure(figsize=(20,10))

#Plot 1
plt.subplot(3,2,1)
plt.hist(df['Open'],bins=50, color='green')
plt.xlabel("Open Price")
plt.ylabel("Frequency")
plt.title('Open')
plt.grid()

#Plot 2
plt.subplot(3,2,2)
plt.hist(df['Close'],bins=50, color='red')
plt.xlabel("Close Price")
plt.ylabel("Frequency")
plt.title('Close')
plt.grid()

#Plot 3
plt.subplot(3,2,3)
plt.hist(df['High'],bins=50, color='green')
plt.xlabel("High Price")
plt.ylabel("Frequency")
plt.title('High')
plt.grid()

#Plot 4
plt.subplot(3,2,4)
plt.hist(df['Low'],bins=50, color='red')
plt.xlabel("Low Price")
plt.ylabel("Frequency")
plt.title('Low')
plt.grid()

plt.tight_layout()
plt.show()

# %%
df['Volume'].unique()
# Out:
# array([0.0987041027, 0.210144385 , 0.5943318435, ..., 0.0252161761,
#        0.0148885067, 0.0114630605])

# %% [markdown]
# **Seasonal Decompose**

# %% [markdown]
# **1.Additive Model**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result1=seasonal_decompose(data['Open'],period=365,model='additive')
result1.plot()
plt.plot()
# Out:
# []

# %%
# Plot the decomposed components
plt.figure(figsize=(12, 6))
plt.plot(result1.seasonal, label='Seasonal')
plt.plot(result1.trend, label='Trend')
plt.plot(result1.resid, label='Residual')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.title('Seasonal Decomposition')
plt.show()

# %%
result1.seasonal.plot()
# Out:
# <Axes: >

# %%
result1.trend.plot()
# Out:
# <Axes: >

# %%
result1.resid.plot()
# Out:
# <Axes: >

# %% [markdown]
# **2.Multiplicative Model**

# %%
result2=seasonal_decompose(data['Close'],model='multiplicative',period=365)

# %%
result2.plot()
plt.show()

# %% [markdown]
# **Checking whether data is Stationary OR Not**

# %% [markdown]
# **ADFULLER TEST**

# %%
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# Let, Ho - Data is not stationary ,
#      H1 - Data is stationary

# %%
def adf_test(data):
    if adfuller(data)[1]>0.05:
        print('accept ho, so data is not stationary')
    else:
        print('reject ho, so data is  stationary')

# %%
adf_test(data['Close'])
# Out:
# accept ho, so data is not stationary

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data['Close'])
plt.title('Line Plot',fontdict={'fontsize':20,'color':'black'})
plt.xlabel('Days')
# Out:
# Text(0.5, 0, 'Days')

# %% [markdown]
# **Transformations**

# %% [markdown]
# **1.Applying LOG**

# %%
ts_data_log=np.log(data['Close'])

# %%
adf_test(ts_data_log)
# Out:
# accept ho, so data is not stationary

# %%
plt.figure(figsize=(12,8))
sns.histplot(np.log(data['Close']),kde=True)
plt.title('Hist Plot',fontdict={'fontsize':20,'color':'black'})
plt.xlabel('Days')
# Out:
# Text(0.5, 0, 'Days')

# %% [markdown]
# **2.Moving Average**

# %%
movingAverage = ts_data_log.rolling(window = 12).mean()
movingSTD = ts_data_log.rolling(window = 12).std()
plt.plot(ts_data_log)
plt.plot(movingAverage,color='red')

# %% [markdown]
# **3.Differencing**

# %%
ts_diff=data['Close'].diff()
ts_diff=ts_diff.dropna()

# %%
ts_diff
# Out:
# 1        2.877663
# 2        1.520950
# 3        1.692326
# 4        2.884804
# 5       -0.864014
#           ...
# 6063   -41.050049
# 6064   -18.299804
# 6065    19.599853
# 6066   -14.849853
# 6067    24.949951
# Name: Close, Length: 6067, dtype: float64

# %%
adf_test(ts_diff)
ts_diff.plot()
# Out:
# reject ho, so data is  stationary
# <Axes: >

# %% [markdown]
# **Splitting the Data--> Train & Test Data**

# %% [markdown]
# **Non-Stationary Data**

# %% [markdown]
# Considering Train data-70% & Test data-30% (approx)

# %%
data.shape
# Out:
# (6068, 6)

# %%
train_data1=data['Close'][:4300]
test_data1=data['Close'][4300:]
train_len=len(train_data1)
test_len=len(test_data1)
plt.figure(figsize=(20,8))
sns.lineplot(test_data1,label='Test',color='orange')
sns.lineplot(train_data1,label='Train')
plt.legend()

# %% [markdown]
# **Stationary Data**

# %%
train_data2=ts_diff[:4299]
test_data2=ts_diff[4299:]
plt.figure(figsize=(12,8))
sns.lineplot(test_data2,label='Test',color='Orange')
sns.lineplot(train_data2,label='Train')
plt.legend()

# %% [markdown]
# **ARIMA**

# %%
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %% [markdown]
# **Acf Curve(q)**

# %%
# Plotting the ACF curve

plot_acf(train_data1,lags=20,zero=False,auto_ylims=True)
plt.show()

# %% [markdown]
# **Pacf Curve(p)**

# %%
# Plotting the PACF curve

plot_pacf(train_data1,lags=20,zero=True,auto_ylims=True)
plt.show()

# %%
# !pip install statsmodels

# %%
arima_model1=ARIMA(train_data1,order=(2,1,2)).fit()  # NON_STATIONARY DATA
train_data1_len=len(train_data1)
test_data1_len=len(test_data1)
pred1=arima_model1.predict(start=train_data1_len,end=(train_data1_len+test_data1_len)-1)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
pred1.plot()
test_data1.plot()
# Out:
# <Axes: >

# %%
error1=np.sqrt(mean_squared_error(test_data1,pred1))
error1
# Out:
# 1297.6361716781767

# %%
arima_model2=ARIMA(train_data2,order=(2,1,2)).fit()  # STATIONARY DATA
train_data2_len=len(train_data2)
test_data2_len=len(test_data2)
pred2=arima_model2.predict(start=train_data2_len,end=(train_data2_len+test_data2_len)-1)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ...

# %%
pred2.plot()
test_data2.plot()
# Out:
# <Axes: >

# %%
error2=np.sqrt(mean_squared_error(test_data2,pred2))
error2
# Out:
# 29.094241298841375

# %% [markdown]
# **MODEL BUILDING**

# %%
data=pd.read_csv('RELIANCE.NS.csv')
data
# Out:
#             Date         Open         High          Low        Close  \
# 0     2000-01-03    33.917892    35.945827    33.917892    35.945827
# 1     2000-01-04    36.902668    38.823490    35.888702    38.823490
# 2     2000-01-05    36.652744    41.115627    36.652744    40.344440
# 3     2000-01-06    41.272720    42.943623    41.272720    42.036766
# 4     2000-01-07    42.129593    45.399994    41.843967    44.921570
# ...          ...          ...          ...          ...          ...
# 6074  2024-04-23  2958.000000  2987.000000  2911.100098  2918.649902
# 6075  2024-04-24  2927.000000  2937.100098  2899.000000  2900.350098
# 6076  2024-04-25  2885.000000  2935.949951  2883.000000  2919.949951
# 6077  2024-04-26  2927.899902  2930.000000  2900.000000  2905.100098
# 6078  2024-04-29  2900.000000  2935.800049  2900.000000  2930.050049
#
#         Adj Close       Volume
# 0       26.684866   31204789.0
# 1       28.821142   66436055.0
# 2       29.950235  187894923.0
# ...

# %%
data['Date']=pd.to_datetime(data['Date'])
data.set_index('Date',inplace=True)

# %%
new_data=data[['Close']]
new_data
# Out:
#                   Close
# Date
# 2000-01-03    35.945827
# 2000-01-04    38.823490
# 2000-01-05    40.344440
# 2000-01-06    42.036766
# 2000-01-07    44.921570
# ...                 ...
# 2024-04-23  2918.649902
# 2024-04-24  2900.350098
# 2024-04-25  2919.949951
# 2024-04-26  2905.100098
# 2024-04-29  2930.050049
#
# [6079 rows x 1 columns]

# %%
sns.lineplot(new_data)
plt.show()

# %%
new_data.dropna(inplace=True) #missing values
# Out:
# <ipython-input-74-716854afab52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.dropna(inplace=True) #missing values

# %%
minmax=MinMaxScaler(feature_range=(0,1))  # Scaling
new_data=minmax.fit_transform(np.array(new_data))

# %%
new_data.shape
# Out:
# (6069, 1)

# %%
new_data
# Out:
# array([[0.0023197923],
#        [0.0032835815],
#        [0.0037929793],
#        ...,
#        [0.9682327303],
#        [0.9632592058],
#        [0.9716154631]])

# %% [markdown]
# **Train & Test data sets**

# %%
train=new_data[:4300]
test=new_data[4300:]

# %%
plt.plot(train,color='green')
plt.plot(test,color='red')
plt.show()

# %%
def prepare_data(data,n_features):
    x,y = [],[]
    for i in range(len(data)):
        end_ix = i + n_features
        if end_ix > len(data) - 1:
            break
        seq_x,seq_y = data[i:end_ix],data[end_ix]
        x.append(seq_x)
        y.append(seq_y)
    x = np.array(x)
    y = np.array(y)

    # Flatten each sequence in x to create a 2D array
    x = x.reshape((x.shape[0],-1))

    return x,y

# %%
x_train,y_train=prepare_data(train,70)

# %%
x_test,y_test=prepare_data(test,70)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4230, 70)
# (1699, 70)
# (4230, 1)
# (1699, 1)

# %%
print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
# [[0.0023197923 0.0032835815 0.0037929793 ... 0.0047376374 0.0058807931
#   0.0071291762]
#  [0.0032835815 0.0037929793 0.0043597744 ... 0.0058807931 0.0071291762
#   0.007717494 ]
#  [0.0037929793 0.0043597744 0.0053259553 ... 0.0071291762 0.007717494
#   0.0072009222]
#  ...
#  [0.1411598334 0.14133591   0.1399885099 ... 0.1549554465 0.1549401352
#   0.1569000066]
#  [0.14133591   0.1399885099 0.1414813748 ... 0.1549401352 0.1569000066
#   0.1751665687]
#  [0.1399885099 0.1414813748 0.1420938361 ... 0.1569000066 0.1751665687
#   0.1713769802]]
# [[0.007717494 ]
#  [0.0072009222]
#  [0.0064451949]
#  ...
#  [0.1751665687]
#  [0.1713769802]
#  [0.1799743707]]
# [[0.1798442168 0.1793006655 0.1796451737 ... 0.1953011261 0.1941833812
#   0.1947958422]
#  [0.1793006655 0.1796451737 0.1829830566 ... 0.1941833812 0.1947958422
#   0.1923077307]
#  [0.1796451737 0.1829830566 0.1901488162 ... 0.1947958422 0.1923077307
#   0.1915268485]
#  ...
# ...

# %% [markdown]
# **1. Linear Regression**

# %%
from sklearn.linear_model import LinearRegression

# %%
multi_linear_model=LinearRegression()

# %%
model1=multi_linear_model.fit(x_train,y_train)

# %%
pred_linear=model1.predict(x_test)

# %% [markdown]
# **perfomance of model**

# %%
from sklearn.metrics import r2_score

# %%
mse_linear=mean_squared_error(y_test,pred_linear)
print(mse_linear)
mae_linear=mean_absolute_error(y_test,pred_linear)
print(mae_linear)
r2_linear=r2_score(y_test,pred_linear)
print(r2_linear)
# Out:
# 0.00010143399786913165
# 0.007104131516576579
# 0.9978266043056477

# %%
plt.figure(figsize=(12,8))
plt.plot(pred_linear,label='Actual',color='red')
plt.plot(y_test,label='Predicted',color='green')
plt.legend()
plt.show()

# %% [markdown]
# **2. Support Vector Machine Regression**

# %%
from sklearn.svm import SVR
from sklearn.metrics import accuracy_score

# %%
svr=SVR(C=1.0,kernel='rbf',gamma=0.1)

# %%
model2=svr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
pred_svr=model2.predict(x_test)
pred_svr
# Out:
# array([0.1354326453, 0.1354577808, 0.1354834505, ..., 0.119788332 ,
#        0.1197678828, 0.1197526184])

# %% [markdown]
# **Performance of model**

# %%
mse_svr=mean_squared_error(y_test,pred_svr)
print(mse_svr)
mae_svr=mean_absolute_error(y_test,pred_svr)
print(mae_svr)
r2_svr=r2_score(y_test,pred_svr)
print(r2_svr)
# Out:
# 0.23399758757581857
# 0.4280026071050267
# -4.013795768774132

# %%
plt.figure(figsize=(12,8))
plt.plot(pred_svr,label='Actual',color='red')
plt.plot(y_test,label='Predicted',color='green')
plt.legend()
plt.show()

# %% [markdown]
# **3. Decision Tree Regression**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dec_tree=DecisionTreeRegressor(splitter='best',min_samples_leaf=5,min_samples_split=10,min_impurity_decrease=0.0,max_leaf_nodes=None,max_features=None,criterion='friedman_mse',ccp_alpha=0.0)

# %%
model3=dec_tree.fit(x_train,y_train)

# %%
pred_dec=model3.predict(x_test)

# %% [markdown]
# **Performance of model**

# %%
mse_dec=mean_squared_error(y_test,pred_dec)
print(mse_dec)
mae_dec=mean_absolute_error(y_test,pred_dec)
print(mae_dec)
r2_dec=r2_score(y_test,pred_dec)
print(r2_dec)
# Out:
# 0.16177204571633805
# 0.33972893086536965
# -2.4662408562468863

# %%
plt.figure(figsize=(12,8))
plt.plot(pred_dec,label='Actual',color='red')
plt.plot(y_test,label='Predicted',color='Green')
plt.legend()
plt.show()

# %% [markdown]
# **4. Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    'bootstrap': [True, False]
}

# %%
random=RandomForestRegressor(bootstrap=True,max_depth=20,max_features='sqrt',min_samples_split=2,min_samples_leaf=2,n_estimators=100)

# %%
model4=random.fit(x_train,y_train)
# Out:
# <ipython-input-107-46a9b6416cf9>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model4=random.fit(x_train,y_train)

# %%
pred_random=model4.predict(x_test)

# %%
mse_random=mean_squared_error(y_test,pred_random)
print(mse_random)
mae_random=mean_absolute_error(y_test,pred_random)
print(mae_random)
r2_random=r2_score(y_test,pred_random)
print(r2_random)
# Out:
# 0.1791555950569769
# 0.3638613407945506
# -2.83871292757596

# %%
plt.figure(figsize=(12,8))
plt.plot(pred_random,label='Actual',color='red')
plt.plot(y_test,label='Predicted',color='green')
plt.show()

# %%
result=pd.DataFrame({'Model':['Linear Regression','Support Vector Machine','Decision Tree','Random Forest']
                     ,'MSE':[mse_linear,mse_svr,mse_dec,mse_random],
                     'MAE':[mae_linear,mae_svr,mae_dec,mae_random],
                     'R2':[r2_linear,r2_svr,r2_dec,r2_random]})

# %%
result.sort_values('MSE')
# Out:
#                     Model       MSE       MAE        R2
# 0       Linear Regression  0.000101  0.007104  0.997827
# 2           Decision Tree  0.161772  0.339729 -2.466241
# 3           Random Forest  0.179156  0.363861 -2.838713
# 1  Support Vector Machine  0.233998  0.428003 -4.013796

# %% [markdown]
# *Hence , Linear Regression model is best to fit for given data(lower of MSE value).*

# %% [markdown]
# **Model Evaluation**

# %%
results=y_test-pred_linear
results
# Out:
# array([[-0.0017976328],
#        [-0.0012988835],
#        [ 0.0069689137],
#        ...,
#        [ 0.0073035751],
#        [-0.0025161116],
#        [ 0.0109122192]])

# %%
plt.figure(figsize=(10,6))
plt.scatter(pred_linear,results)

# %%
sns.histplot(results,bins=50,kde=True,color='blue')
plt.show()

# %% [markdown]
# **Forescasting Results**

# %%
try:
    x_forecast, y_forecast = prepare_data(new_data, 70)
    print("x_forecast shape:", x_forecast.shape)
    print("y_forecast shape:", y_forecast.shape)
except KeyError as e:
    print(f"KeyError: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# x_forecast shape: (5999, 70)
# y_forecast shape: (5999, 1)

# %%
linear=LinearRegression()

# %%
model=linear.fit(x_forecast,y_forecast)

# %%
pred=model.predict(x_forecast)

# %%
plt.figure(figsize=(12,8))
plt.plot(pred,label='Predicted',color='green')
plt.plot(y_forecast,label='Actual',color='red')
plt.legend()
plt.show()

# %%
last_days=test[-70:]

# %%
type(last_days)
# Out:
# numpy.ndarray

# %%
future=[]
n_features=70
numberofdays=241
for i in range (numberofdays):
    x = last_days.reshape((1, n_features))
    final=linear.predict(x)[0]
    future.append(final)
    last_days = np.append(last_days[1:], final)

# %%
start_date = '2024-04-30'
end_date = '2025-04-01'

dates = pd.bdate_range(start=start_date, end=end_date)

# Print the dates
print(dates)
# Out:
# DatetimeIndex(['2024-04-30', '2024-05-01', '2024-05-02', '2024-05-03',
#                '2024-05-06', '2024-05-07', '2024-05-08', '2024-05-09',
#                '2024-05-10', '2024-05-13',
#                ...
#                '2025-03-19', '2025-03-20', '2025-03-21', '2025-03-24',
#                '2025-03-25', '2025-03-26', '2025-03-27', '2025-03-28',
#                '2025-03-31', '2025-04-01'],
#               dtype='datetime64[ns]', length=241, freq='B')

# %%
data= [val[0] for val in future]

# %%
forecast_data=pd.DataFrame()

# %%
forecast_data['Dates']=dates
forecast_data['Predicted_values']=data

# %%
forecast_data
# Out:
#          Dates  Predicted_values
# 0   2024-04-30          0.967695
# 1   2024-05-01          0.966822
# 2   2024-05-02          0.972929
# 3   2024-05-03          0.976613
# 4   2024-05-06          0.971919
# ..         ...               ...
# 236 2025-03-26          1.104045
# 237 2025-03-27          1.104635
# 238 2025-03-28          1.105224
# 239 2025-03-31          1.105802
# 240 2025-04-01          1.106389
#
# [241 rows x 2 columns]

# %%
forecast_data['Predicted_values']=minmax.inverse_transform(forecast_data[['Predicted_values']])

# %%
forecast_data
# Out:
#          Dates  Predicted_values
# 0   2024-04-30       2918.344700
# 1   2024-05-01       2915.738634
# 2   2024-05-02       2933.971794
# 3   2024-05-03       2944.970653
# 4   2024-05-06       2930.954857
# ..         ...               ...
# 236 2025-03-26       3325.454777
# 237 2025-03-27       3327.216402
# 238 2025-03-28       3328.975005
# 239 2025-03-31       3330.702563
# 240 2025-04-01       3332.455481
#
# [241 rows x 2 columns]

# %% [markdown]
# **MODEL DEPLOYMENT**

# %%
import pickle

# %%
file='linear.pkl'

# %%
pickle.dump(model,open(file,'wb'))
